# %%
import skimage
from skimage import io
from skimage.color import rgb2gray
from skimage import data
import numpy as np
a=io.imread(r"C:\Users\Shreyas I\Desktop\royce.jpg")
io.imshow(a)
io.show()




print(a.size)
b=rgb2gray(a)
io.imshow(b)


r,c=np.shape(b)

for i in range(1,r):
    for j in range(1,c):
        if i>500 and i<800:
            if j>500 and j<800:
                b[i][j]=0                
print(b)
io.imshow(b)
io.show()
# Out:
# 6220800
# (1080, 1920)
# 0.25510828814451714
# 1080
# 1920
# [[0.33538784 0.33538784 0.33622118 ... 0.06611686 0.05099608 0.04091294]
#  [0.33146627 0.33229961 0.33229961 ... 0.06611686 0.05491765 0.06444235]
#  [0.32642078 0.32642078 0.33034235 ... 0.07844706 0.05659922 0.08825451]
#  ...
#  [0.64023451 0.63239137 0.62062667 ... 0.53275294 0.50138039 0.49745882]
#  [0.60523098 0.60523098 0.60130941 ... 0.5876549  0.59157647 0.60726275]
#  [0.61699569 0.62483882 0.63660353 ... 0.59549804 0.61118431 0.63863529]]
